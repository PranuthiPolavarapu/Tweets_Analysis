# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Lets read the two csv files
user=pd.read_csv('userdata.csv')
tweet=pd.read_csv('tweetdata.csv')

# %%
user.head(5)
# Out:
#    Unnamed: 0         username        displayname               userId  \
# 0           0   ShashiRajbhar6     Shashi Rajbhar  1015969769760096256
# 1           1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 2           3    SukhdevSingh_      Sukhdev Singh  1308356658582618112
# 3           4  Davidmu66668113     tera jija 🤨🚩🇺🇸  1357311756532649985
# 4           5   Abhimanyu_1987     Abhimanyu 🌏 🇮🇳           2918610912
#
#                                       rawDescription descriptionUrls  \
# 0  Satya presan 🤔ho Sakta but prajit💪 nhi\njhuth ...              []
# 1        ਜਿਓਣਾ ਕੀ ਸਰੀਰਾਂ ਦਾ ਜੇਕਰ ਹੋਣ ਜ਼ਮੀਰਾਂ ਮਰੀਆਂ 🌼              []
# 2  Just a part of my society . Social and Politic...              []
# 3                                     dream boy 🌪🌍🔥💯              []
# 4                                          Seeker...              []
#
#    verified                    created  followersCount  friendsCount  \
# ...

# %%
tweet.head(5)
# Out:
#    Unnamed: 0                                           tweetUrl  \
# 0           0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1           1  https://twitter.com/kaursuk06272818/status/137...
# 2           2  https://twitter.com/kaursuk06272818/status/137...
# 3           3  https://twitter.com/SukhdevSingh_/status/13767...
# 4           4  https://twitter.com/Davidmu66668113/status/137...
#
#                         date  \
# 0  2021-03-30 03:33:46+00:00
# 1  2021-03-30 03:33:23+00:00
# 2  2021-03-30 03:31:00+00:00
# 3  2021-03-30 03:30:45+00:00
# 4  2021-03-30 03:30:30+00:00
#
#                                      renderedContent              tweetId  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
# 3  #StopHateAgainstFarmers support #FarmersProtes...  1376738640542400518
# ...

# %%
#Using the merge function and the outer join lets join two csv files on userId
data=pd.merge(user,tweet,on='userId',how='outer')

# %%
data
# Out:
#         Unnamed: 0_x         username        displayname               userId  \
# 0                  0   ShashiRajbhar6     Shashi Rajbhar  1015969769760096256
# 1                  1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 2                  1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 3                  1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 4                  1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# ...              ...              ...                ...                  ...
# 109578        109527        Yaqoob585    Muhammad Yaqoob  1356069057754136576
# 109579        109542  Gurpree62630454     Gurpreet Singh  1354775861816266754
# 109580        109551        Patiala5S       Garry Bhangu  1332900172142157825
# 109581        109573       RJ_Naveed_      RJ Naveed 😘🇮🇳  1218021912489668609
# 109582        109578     Girds_canada       Girds Canada  1347232536661950465
#
# ...

# %%
#check for null values
data.isnull()
# Out:
#         Unnamed: 0_x  username  displayname  userId  rawDescription  \
# 0              False     False        False   False           False
# 1              False     False        False   False           False
# 2              False     False        False   False           False
# 3              False     False        False   False           False
# 4              False     False        False   False           False
# ...              ...       ...          ...     ...             ...
# 109578         False     False        False   False           False
# 109579         False     False        False   False            True
# 109580         False     False        False   False            True
# 109581         False     False        False   False           False
# 109582         False     False        False   False           False
#
#         descriptionUrls  verified  created  followersCount  friendsCount  ...  \
# ...

# %%
#drop the null values
cleaned=data.dropna(axis=1,how='all')

# %%
cleaned.isnull()
# Out:
#         Unnamed: 0_x  username  displayname  userId  rawDescription  \
# 0              False     False        False   False           False
# 1              False     False        False   False           False
# 2              False     False        False   False           False
# 3              False     False        False   False           False
# 4              False     False        False   False           False
# ...              ...       ...          ...     ...             ...
# 109578         False     False        False   False           False
# 109579         False     False        False   False            True
# 109580         False     False        False   False            True
# 109581         False     False        False   False           False
# 109582         False     False        False   False           False
#
#         descriptionUrls  verified  created  followersCount  friendsCount  ...  \
# ...

# %%
cleaned.fillna(0,inplace=True)
# Out:
# /var/folders/5p/2k0xyy_d1p79mw98h7gchw9m0000gn/T/ipykernel_59728/957444357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned.fillna(0,inplace=True)

# %%
cleaned
# Out:
#         Unnamed: 0_x         username        displayname               userId  \
# 0                  0   ShashiRajbhar6     Shashi Rajbhar  1015969769760096256
# 1                  1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 2                  1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 3                  1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 4                  1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# ...              ...              ...                ...                  ...
# 109578        109527        Yaqoob585    Muhammad Yaqoob  1356069057754136576
# 109579        109542  Gurpree62630454     Gurpreet Singh  1354775861816266754
# 109580        109551        Patiala5S       Garry Bhangu  1332900172142157825
# 109581        109573       RJ_Naveed_      RJ Naveed 😘🇮🇳  1218021912489668609
# 109582        109578     Girds_canada       Girds Canada  1347232536661950465
#
# ...

# %%
df=pd.pivot_table(cleaned, values='followersCount',index='username',columns='verified')

# %%
verified=df.sort_values(by=1,ascending=False)

# %%
# Top 3 verified users based on the follower count
topver=verified.head(3)
topver
# Out:
# verified      False        True
# username
# ndtv            NaN  14916347.0
# timesofindia    NaN  13454032.0
# ABPNews         NaN  10993100.0

# %%
chart1=topver.plot.bar(figsize=(10,8))
chart1.set_title('Top 3 verified users based on followers')
chart1.set_xlabel('username')
chart1.set_ylabel('followers')
# Out:
# Text(0, 0.5, 'followers')

# %%
# top 5 users with more friends count
df1=pd.pivot_table(cleaned, values='friendsCount',index='username')

# %% [markdown]
# #

# %%
df1=df1.sort_values(by='friendsCount',ascending=False)

# %%
df1.head(5)
# Out:
#               friendsCount
# username
# jaggirm             319773
# yespunjab           149605
# TheTeamModi          47104
# BNN_Breaking         38489
# NYFarmer             36549

# %%
df2=pd.pivot_table(cleaned, values='retweetCount',index='username')

# %%
df2=df2.sort_values(by='retweetCount',ascending=False)

# %%
topretweet=df2.head(5)

# %%
chart2=topretweet.plot.bar(figsize=(10,8))
chart2.set_title('Top 5 users with highest retweets')
chart2.set_xlabel('username')
chart2.set_ylabel('retweet count')
# Out:
# Text(0, 0.5, 'retweet count')
